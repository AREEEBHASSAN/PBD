# %%
list=[1,2,3,4]

# %%
list
# Out:
# [1, 2, 3, 4]

# %%
list[0]
# Out:
# 1

# %%
list[-1]
# Out:
# 4

# %%
list[-2]
# Out:
# 3

# %%
list=list+["areeb"]

# %%
list
# Out:
# [1, 2, 3, 4, 'areeb']

# %%
list.extend([5,6,7])

# %%
list1=[2,3,4]
list1
# Out:
# [2, 3, 4]

# %%
list1.extend([1])
list1
# Out:
# [2, 3, 4, 1, 1, [4], 4, 1]

# %%
list1.append(4)
list1
# Out:
# [2, 3, 4, 1, 1, [4], 4]

# %%
list1[-1]
list1
# Out:
# [2, 3, 4]

# %%
list2=[22,344,55,"unk"]
list2
# Out:
# [22, 344, 55, 'unk']

# %%
list2=list2+["areeb"]

# %%
list2
list2.append(["areeb,faaz"])

# %%
list2[-1][0][0]
list2
# Out:
# [22, 344, 55, 'unk', 'areeb', ['areeb,faaz']]

# %%
list2[-1]
# Out:
# ['areeb,faaz']

# %%
list2[-2]
# Out:
# 'areeb'

# %%
list2[-2][1][0]  #row or column +-1 is last index value
# Out:
# 'r'

# %%
#REMOVE()
#DELTETE []
#POP()

# %%
list2
# Out:
# [55, 'unk', 'areeb', ['areeb,faaz']]

# %%
list2
# Out:
# [55, 'unk', 'areeb', ['areeb,faaz']]

# %%
list2.insert(3,444)
list2
# Out:
# [55,
#  444,
#  2,
#  444,
#  444,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  'unk',
#  'areeb',
#  ['areeb,faaz']]

# %%
del list2[0:17]
list2
# Out:
# []

# %%
list2.insert(3,4)
list2
list2.pop()
# Out:
# 4

# %%
list3=[3,2,1,"perrooo"]
list3
# Out:
# [3, 2, 1, 'perrooo']

# %%
for x in list3:
    print(x)
if type(x)==str:
    list3.remove(x)
list3
list3.sort()
list3
# Out:
# 3
# [3]

# %%
# Out:
# [3]

# %%
list4=[2,3,4,6,7]
list4
# Out:
# [2, 3, 4, 6, 7]

# %%
list4.sort(reverse=True)
list4
# Out:
# [7, 6, 4, 3, 2]

# %%
d={'country':["pakistan","china","india"],
  'Capital':["islamabad",'bejing','dehli'],
  'population':[1.34,6.7,6.8] }
d
# Out:
# {'country': ['pakistan', 'china', 'india'],
#  'Capital': ['islamabad', 'bejing', 'dehli'],
#  'population': [1.34, 6.7, 6.8]}

# %%
d.values()
d.items()
# Out:
# dict_items([('country', ['pakistan', 'china', 'india']), ('Capital', ['islamabad', 'bejing', 'dehli']), ('population', [1.34, 6.7, 6.8])])

# %%
d.keys()
# Out:
# dict_keys(['country', 'Capital', 'population'])

# %%
for x in d.items():
    print(x)
# Out:
# ('country', ['pakistan', 'china', 'india'])
# ('Capital', ['islamabad', 'bejing', 'dehli'])
# ('population', [1.34, 6.7, 6.8])

# %%
for x in d.keys():
    print(x)
# Out:
# country
# Capital
# population

# %%
import pandas as pd
df=pd.DataFrame.from_dict(d)
df
# Out:
#     country    Capital  population
# 0  pakistan  islamabad        1.34
# 1     china     bejing        6.70
# 2     india      dehli        6.80

# %%
df.to_csv('pdb_d4.csv',index=False,header=True)
pd.read_csv('pdb_d4.csv')
# Out:
#     country    Capital  population
# 0  pakistan  islamabad        1.34
# 1     china     bejing        6.70
# 2     india      dehli        6.80

# %%
df.head(1)
# Out:
#     country    Capital  population
# 0  pakistan  islamabad        1.34

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# # PANDAS CONTINUED

# %%
import pandas as pd
df=pd.read_csv("auto.csv")

# %%
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns=headers
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.tail(10)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 194         -1                74  volvo       gas        std         four
# 195         -2               103  volvo       gas        std         four
# 196         -1                74  volvo       gas        std         four
# 197         -2               103  volvo       gas      turbo         four
# 198         -1                74  volvo       gas      turbo         four
# 199         -1                95  volvo       gas        std         four
# 200         -1                95  volvo       gas      turbo         four
# 201         -1                95  volvo       gas        std         four
# 202         -1                95  volvo    diesel      turbo         four
# 203         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 194      wagon          rwd           front       104.3  ...          141
# ...

# %%
df['drive-wheels'].head(7)#for ingle column
# Out:
# 0    rwd
# 1    rwd
# 2    fwd
# 3    4wd
# 4    fwd
# 5    fwd
# 6    fwd
# Name: drive-wheels, dtype: object

# %%
df[['drive-wheels','body-style','normalized-losses']].head(7)#for two or more column make 2d array
# Out:
#   drive-wheels   body-style normalized-losses
# 0          rwd  convertible                 ?
# 1          rwd    hatchback                 ?
# 2          fwd        sedan               164
# 3          4wd        sedan               164
# 4          fwd        sedan                 ?
# 5          fwd        sedan               158
# 6          fwd        wagon                 ?

# %%
#numpy is a libraray put nan inplace of symbol which user not entered data he will supposed automatically and replace it

# %%
import numpy as np
df.replace("?",np.nan,inplace=True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False               True  False      False       False         False
# 1        False               True  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False               True  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 199      False              False  False      False       False         False
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
#
# ...

# %%
df.isnull().sum() #count the frequency of true
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df['normalized-losses'].head()
# Out:
# 0      NaN
# 1      NaN
# 2    164.0
# 3    164.0
# 4      NaN
# Name: normalized-losses, dtype: float64

# %%
m=df['normalized-losses'].astype('float').mean() #step2
m
# Out:
# 122.0

# %%
df['normalized-losses']=df['normalized-losses'].astype('float')#file change permanenetly
df#step 1
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df['normalized-losses'].replace(np.nan,m,inplace=True)#step3
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df['normalized-losses'].head() #step 4
# Out:
# 0    122.0
# 1    122.0
# 2    164.0
# 3    164.0
# 4    122.0
# Name: normalized-losses, dtype: float64

# %%
df.isnull().sum()#step5
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df['num-of-doors'].head(9)
# Out:
# 0     two
# 1     two
# 2    four
# 3    four
# 4     two
# 5    four
# 6    four
# 7    four
# 8     two
# Name: num-of-doors, dtype: object

# %%
df['num-of-doors'].value_counts()
# Out:
# four    114
# two      88
# Name: num-of-doors, dtype: int64

# %%
df['num-of-doors'].value_counts().max()
# Out:
# 114

# %%
mx=df['num-of-doors'].value_counts().idxmax()

# %%
df['num-of-doors'].replace(np.nan,mx,inplace=True)
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df['bore'].value_counts().max()
# Out:
# 23

# %%
df['bore'].head()
# Out:
# 0    3.47
# 1    2.68
# 2    3.19
# 3    3.19
# 4    3.19
# Name: bore, dtype: object

# %%
mx=df['bore'].astype('float').mean()

# %%
df['bore'].replace(np.nan,mx,inplace=True)
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
mx=df['stroke'].astype('float').mean()
# Out:
# 3.258299999999994

# %%
#df['stroke'].astype('float')
# Out:
# 4.17

# %%
#df['stroke'].astype('float').idxmax()
# Out:
# 46

# %%
df['stroke'].head()
# Out:
# 0    2.68
# 1    3.47
# 2    3.40
# 3    3.40
# 4    3.40
# Name: stroke, dtype: object

# %%
df['stroke'].replace(np.nan,mx,inplace=True)
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df['horsepower'].head()
# Out:
# 0    111
# 1    154
# 2    102
# 3    115
# 4    110
# Name: horsepower, dtype: object

# %%
mx=df['horsepower'].astype('float').mean()
# Out:
# 104.22277227722772

# %%
df['horsepower'].replace(np.nan,mx,inplace=True)
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df['peak-rpm'].head()
# Out:
# 0    5000
# 1    5000
# 2    5500
# 3    5500
# 4    5500
# Name: peak-rpm, dtype: object

# %%
mx=df['peak-rpm'].astype('float').mean()
# Out:
# 5125.990099009901

# %%
df['peak-rpm'].replace(np.nan,mx,inplace=True)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            1              122.0  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              122.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df['price'].head()
# Out:
# 0    16500
# 1    16500
# 2    13950
# 3    17450
# 4    15250
# Name: price, dtype: object

# %%
mx=df['price'].astype('float').mean()

# %%
df['price'].replace(np.nan,mx,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64
